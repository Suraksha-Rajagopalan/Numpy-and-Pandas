# %%
import pandas as pd

data=pd.read_csv(r"C:\Users\SUDHA\Downloads\nba.csv")

# %%
data
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
grouped_data = data.groupby('Team')
grouped_data.first()
# Out:
#                                          Name  Number Position   Age Height  \
# Team
# Atlanta Hawks                   Kent Bazemore    24.0       SF  26.0    6-5
# Boston Celtics                  Avery Bradley     0.0       PG  25.0    6-2
# Brooklyn Nets                Bojan Bogdanovic    44.0       SG  27.0    6-8
# Charlotte Hornets               Nicolas Batum     5.0       SG  27.0    6-8
# Chicago Bulls                Cameron Bairstow    41.0       PF  25.0    6-9
# Cleveland Cavaliers       Matthew Dellavedova     8.0       PG  25.0    6-4
# Dallas Mavericks              Justin Anderson     1.0       SG  22.0    6-6
# Denver Nuggets                 Darrell Arthur     0.0       PF  28.0    6-9
# Detroit Pistons                  Joel Anthony    50.0        C  33.0    6-9
# Golden State Warriors         Leandro Barbosa    19.0       SG  33.0    6-3
# Houston Rockets                  Trevor Ariza     1.0       SF  30.0    6-8
# ...

# %%
grouped_data.get_group("Charlotte Hornets")
# Out:
#                        Name  Number Position   Age Height  Weight  \
# 324           Nicolas Batum     5.0       SG  27.0    6-8   200.0
# 325            Troy Daniels    30.0       SG  24.0    6-4   205.0
# 326         Jorge Gutierrez    12.0       PG  27.0    6-3   189.0
# 327        Tyler Hansbrough    50.0       PF  30.0    6-9   250.0
# 328          Aaron Harrison     9.0       SG  21.0    6-6   210.0
# 329           Spencer Hawes     0.0       PF  28.0    7-1   245.0
# 330            Al Jefferson    25.0        C  31.0   6-10   289.0
# 331      Frank Kaminsky III    44.0        C  23.0    7-0   240.0
# 332  Michael Kidd-Gilchrist    14.0       SF  22.0    6-7   232.0
# 333             Jeremy Lamb     3.0       SG  24.0    6-5   185.0
# 334            Courtney Lee     1.0       SG  30.0    6-5   200.0
# 335              Jeremy Lin     7.0       PG  27.0    6-3   200.0
# 336            Kemba Walker    15.0       PG  26.0    6-1   184.0
# ...

# %%
data.groupby('Team')[['Salary','Age']].agg({'Salary':['mean','sum'], 'Age':['max','min']})
# Out:
#                               Salary                Age
#                                 mean          sum   max   min
# Team
# Atlanta Hawks           4.860197e+06   72902950.0  35.0  22.0
# Boston Celtics          4.181505e+06   58541068.0  29.0  20.0
# Brooklyn Nets           3.501898e+06   52528475.0  32.0  21.0
# Charlotte Hornets       5.222728e+06   78340920.0  31.0  21.0
# Chicago Bulls           5.785559e+06   86783378.0  35.0  21.0
# Cleveland Cavaliers     7.642049e+06  106988689.0  35.0  24.0
# Dallas Mavericks        4.746582e+06   71198732.0  37.0  22.0
# Denver Nuggets          4.294424e+06   60121930.0  36.0  20.0
# Detroit Pistons         4.477884e+06   67168263.0  36.0  20.0
# Golden State Warriors   5.924600e+06   88868997.0  33.0  20.0
# Houston Rockets         5.018868e+06   75283021.0  38.0  22.0
# Indiana Pacers          4.450122e+06   66751826.0  30.0  20.0
# Los Angeles Clippers    6.323643e+06   94854640.0  39.0  23.0
# ...
